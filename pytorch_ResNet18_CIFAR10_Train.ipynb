# %% [markdown]
# <a href="https://colab.research.google.com/github/godlejr/PytorchSkeleton/blob/main/pytorch_ResNet18_CIFAR10_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2]) #중첩사용을 위해

# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.140625
# Current benign train loss: 2.3495121002197266
#
# Current batch: 100
# Current benign train accuracy: 0.21875
# Current benign train loss: 2.043498992919922
#
# Current batch: 200
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.879835844039917
#
# Current batch: 300
# Current benign train accuracy: 0.40625
# Current benign train loss: 1.6791306734085083
#
# Total benign train accuarcy: 30.84
# Total benign train loss: 759.2870433330536
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 37.99
# Test average loss: 0.017667591786384582
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.34375
# Current benign train loss: 1.6473256349563599
#
# Current batch: 100
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.4130926132202148
#
# Current batch: 200
# Current benign train accuracy: 0.3828125
# Current benign train loss: 1.5721733570098877
#
# Current batch: 300
# Current benign train accuracy: 0.4765625
# Current benign train loss: 1.4899866580963135
#
# Total benign train accuarcy: 46.03
# Total benign train loss: 573.7255053520203
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 47.91
# Test average loss: 0.014617325294017791
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5
# Current benign train loss: 1.42536461353302
#
# Current batch: 100
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.159989356994629
#
# Current batch: 200
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1581984758377075
#
# Current batch: 300
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.3145349025726318
#
# Total benign train accuarcy: 56.486
# Total benign train loss: 471.010999083519
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 40.91
# Test average loss: 0.01846780366897583
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.1876460313796997
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.998107373714447
#
# Current batch: 200
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.9953046441078186
#
# Current batch: 300
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8930248022079468
#
# Total benign train accuarcy: 64.648
# Total benign train loss: 389.17329889535904
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 54.75
# Test average loss: 0.012816807281970977
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.9454345703125
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7674018740653992
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6160848140716553
#
# Current batch: 300
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8398686647415161
#
# Total benign train accuarcy: 69.122
# Total benign train loss: 341.22464483976364
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 64.18
# Test average loss: 0.01045539071559906
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8536533713340759
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6734568476676941
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6043394804000854
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7406826615333557
#
# Total benign train accuarcy: 72.84
# Total benign train loss: 304.4991614818573
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 68.76
# Test average loss: 0.008871597743034363
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6413114070892334
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6502847075462341
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5450312495231628
#
# Current batch: 300
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7021723389625549
#
# Total benign train accuarcy: 76.308
# Total benign train loss: 266.1933237016201
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 71.77
# Test average loss: 0.008348997259140015
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7708004713058472
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6258472204208374
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5198226571083069
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6070865392684937
#
# Total benign train accuarcy: 78.798
# Total benign train loss: 237.27881345152855
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 70.39
# Test average loss: 0.008546131092309952
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.460396409034729
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.524608314037323
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5558926463127136
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6435846090316772
#
# Total benign train accuarcy: 81.184
# Total benign train loss: 213.6175244152546
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 76.28
# Test average loss: 0.007024407210946083
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.45638275146484375
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.45735567808151245
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4214678406715393
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6497885584831238
#
# Total benign train accuarcy: 82.52
# Total benign train loss: 196.23446568846703
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 67.69
# Test average loss: 0.010247152674198151
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4936017394065857
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4444059431552887
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.46182724833488464
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5310220122337341
#
# Total benign train accuarcy: 83.912
# Total benign train loss: 182.64782264828682
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 82.12
# Test average loss: 0.005242932426929474
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.40482914447784424
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.42014139890670776
#
# Current batch: 200
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3377959430217743
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5254374742507935
#
# Total benign train accuarcy: 84.828
# Total benign train loss: 170.8220065832138
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 83.07
# Test average loss: 0.004942805162072182
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.32545098662376404
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.449244886636734
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.48607337474823
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4957199990749359
#
# Total benign train accuarcy: 85.896
# Total benign train loss: 158.82548433542252
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 82.2
# Test average loss: 0.005287285137176513
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5079894065856934
#
# Current batch: 100
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3086712658405304
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4330078363418579
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3309120833873749
#
# Total benign train accuarcy: 86.646
# Total benign train loss: 151.6056751459837
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 79.79
# Test average loss: 0.006181740352511406
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.373007208108902
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4595564901828766
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3697037696838379
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.44323211908340454
#
# Total benign train accuarcy: 87.126
# Total benign train loss: 145.44607466459274
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 82.42
# Test average loss: 0.005240431708097458
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.35081905126571655
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3282155394554138
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2642815113067627
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.27240151166915894
#
# Total benign train accuarcy: 87.59
# Total benign train loss: 139.28759318590164
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 84.37
# Test average loss: 0.004637461644411087
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4136975109577179
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.24004782736301422
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4573454260826111
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5008299350738525
#
# Total benign train accuarcy: 88.258
# Total benign train loss: 132.505024433136
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 81.42
# Test average loss: 0.005745909109711647
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3745274841785431
#
# Current batch: 100
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3181147575378418
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3464580178260803
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.36427709460258484
#
# Total benign train accuarcy: 88.36
# Total benign train loss: 131.39693468809128
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 82.06
# Test average loss: 0.005449995279312134
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2759522795677185
#
# Current batch: 100
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3275628387928009
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.35424673557281494
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3523884415626526
#
# Total benign train accuarcy: 89.026
# Total benign train loss: 125.59219136834145
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 84.94
# Test average loss: 0.00459710858464241
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3452222943305969
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.27105966210365295
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3947826027870178
#
# Current batch: 300
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3150211274623871
#
# Total benign train accuarcy: 89.148
# Total benign train loss: 122.70101415365934
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 84.58
# Test average loss: 0.004738946920633316
# Model Saved!
